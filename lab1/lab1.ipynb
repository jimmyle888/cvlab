# %% [markdown]
# # Lab 1

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
img = plt.imread('img2.jpg')
plt.imshow(img)

# %%
red = img[:,:,2].copy()
blue = img[:,:,0].copy()

img[:,:,0] = red
img[:,:,2] = blue
plt.imshow(img)

# %%
img_g = plt.imread('img2.jpg')
plt.imshow(img_g)

# %%
img_g[:,:,0] = 0 #red
img_g[:,:,2] = 0 #blue
plt.imshow(img_g)

# %%
img_r = plt.imread('img2.jpg')
plt.imshow(img_r)

# %%
img_r[:,:,1] = 0 #green
img_r[:,:,2] = 0 #blue
plt.imshow(img_r)

# %%
img_grey = plt.imread('img2.jpg')
plt.imshow(img_grey)

# %%
#img_grey[:,:,0].astype(np.float32)/255 

#Conversion to fp

img_gr = img_grey.astype(np.float32)/255

img_gr = (img_gr[:,:,0]+ img_gr[:,:,1]+ img_gr[:,:,2]) / 3

# %%
plt.imshow(img_gr) #By default creates a density map, we must set cmap to grey

# %%
plt.imshow(img_gr, cmap='Greys_r') #Use 'Greys' for greyscale or 'Greys_r' for inverse greyscale

# %%
centerx, centery = [int(img.shape[0] / 2) - 50, int(img.shape[1] / 2) - 50]
img_center = img_gr[centerx:centerx + 100, centery:centery + 100]

plt.imshow(img_center)

# %%
img2 = plt.imread('img1.png')
plt.imshow(img2)

# %%
img2_gr = img2.astype(np.float32)/255

img2_gr = (img2_gr[:,:,0]+ img2_gr[:,:,1]+ img2_gr[:,:,2]) / 3

# %%
plt.imshow(img2_gr)

# %%
img2_gr[centerx:centerx + 100, centery:centery + 100] = img_center

# %%
plt.imshow(img2_gr)

# %%
plt.imshow(img_gr)

# %%
np.min(img_gr)
# Out:
# 0.22352941

# %%
np.max(img_gr)
# Out:
# 0.95424837

# %%
np.mean(img_gr)
# Out:
# 0.5670889

# %%
np.std(img_gr)
# Out:
# 0.11662427

# %%
mean = np.mean(img_gr)
std = np.std(img_gr)
img_gr = (img_gr - mean) / std * 0.05 + mean

# %%
plt.imshow(img_gr, cmap="Greys")
