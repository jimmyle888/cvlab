# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
#import matplotlib; matplotlib.use('TkAgg')
img = plt.imread('tall_geo.png')
plt.imshow(img)
#plt.ginput(n=9)

# %%
#Order of points:
#Top left road
#Bottom left road
#Bottom right road
#Top right road
#Kosta's head
#Kosta's feet
#George's feet
#George's head

# %%
tl_road = [262.3630520239402, 228.83654425045154]
bl_road = [55.655540602755195, 326.750628607855]
br_road = [862.9027694160144, 316.95922017211456]
tr_road = [714.9437086092715, 249.5072953925701]
kosta_head = [565.8967135318908, 160.29668520026917]
kosta_feet = [565.8967135318908, 284.3211920529801]
george_feet = [522.3793427063781, 439.89579275418777]
george_head = [522.3793427063781, 257.1228352870347]
height_of_kosta_cm = 182.88

# %%
#Finds the euclidian distance between two points
def pixel_dist(a, b):
    return 0
